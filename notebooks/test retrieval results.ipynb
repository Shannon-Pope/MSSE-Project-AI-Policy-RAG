# %%
python scripts/test_retrieval.py

# %% [markdown]
# **How many PTO days do employees receive?**

# %% [markdown]
# Top retrieval results:
#
# Result 1
# Document: Paid Time Off (PTO) Policy
# File: Paid Time Off (PTO) Policy.md
# Page:
# Chunk ID: b482ceb0b179f22fd5ec9c1fcc6ae78d
# Distance: 0.3687  (lower = more similar)
# Snippet:
# ates
#
# ### Full-Time Employees
# Full-time employees accrue PTO at the following rate:
#
# - 1.54 hours per pay period
# - Equivalent to approximately 20 days annually
#
# ### Part-Time Employees
# Part-time employees accrue PTO proportionally based on scheduled work hours.
#
# Accrual rates and balances will be reflected in payroll or HR systems.
#
# ---
#
# ## PTO Usage
# PTO may be used for:
# - Vacation
# - Personal time
# - Illness or medical appointments
# - Mental health and wellness
# - Family care responsibilities
#
# Empl
# --------------------------------------------------------------------------------
# Result 2
# Document: Paid Time Off (PTO) Policy
# File: Paid Time Off (PTO) Policy.md
# Page:
# Chunk ID: 81b9896843b696b27f1a2db270dbd6a7
# Distance: 0.3817  (lower = more similar)
# Snippet:
# # Paid Time Off (PTO) Policy – California Employees
#
# ## Purpose
# The purpose of this policy is to provide paid time off benefits that support employee wellbeing, work-life balance, and compliance with California employment laws.
#
# ---
#
# ## Scope
# This policy applies to all employees based in California.
#
# The company operates primarily on-site in San Diego, California. Eligible employees may participate in hybrid work arrangements with manager approval.
#
# ---
#
# ## Eligibility
#
# ### Full-Time Employees
# F
# --------------------------------------------------------------------------------
# Result 3
# Document: Paid Time Off (PTO) Policy
# File: Paid Time Off (PTO) Policy.md
# Page:
# Chunk ID: 546c55791eaff5ddb5b7c74c8c26dae0
# Distance: 0.4041  (lower = more similar)
# Snippet:
# xceed state and local requirements.
#
# The company complies with:
# - California Healthy Workplaces, Healthy Families Act
# - Applicable San Diego paid sick leave requirements
#
# ---
#
# ## Company Holidays
# The company observes the following holidays:
#
# - New Year’s Day
# - Martin Luther King Jr. Day
# - Memorial Day
# - Juneteenth
# - Independence Day
# - Labor Day
# - Thanksgiving Day
# - Day after Thanksgiving
# - Christmas Eve
# - Christmas Day
#
# Additional floating holidays may be announced annually.
#
# ---
#
# ## Requesting
# --------------------------------------------------------------------------------

# %% [markdown]
# **What is the hotel reimbursement limit?**

# %% [markdown]
# Top retrieval results:
#
# Result 1
# Document: Business Travel Policy
# File: Business Travel Policy.md
# Page:
# Chunk ID: 4255d117cdfd406eeff19020582e58ac
# Distance: 0.3297  (lower = more similar)
# Snippet:
# es
# Hotel reimbursement is limited to:
#
# - $200 per night before taxes and fees
#
# Employees should:
# - Select safe accommodations
# - Stay near the business destination when practical
# - Use reasonable judgment regarding lodging costs
#
# Exceptions require prior approval.
#
# ---
#
# ## Daily Meal Allowance
# Employees are eligible for reimbursement up to:
#
# - $125 per person, per day
#
# The allowance includes:
# - Breakfast
# - Lunch
# - Dinner
# - Reasonable gratuities
#
# Alcohol is generally not reimbursable unless approv
# --------------------------------------------------------------------------------
# Result 2
# Document: Employee Expense Reimbursement Policy
# File: Employee Expense Reimbursement Policy.md
# Page:
# Chunk ID: 707caf5e2e1af6664cb9fa474f0c72b4
# Distance: 0.3888  (lower = more similar)
# Snippet:
# ved travel-related expenses include:
# - Airfare
# - Hotel accommodations
# - Ground transportation
# - Parking and tolls
# - Mileage reimbursement
# - Meals
#
# ### Hybrid & Remote Work
# Employees approved for hybrid work may be reimbursed for necessary business expenses, including:
# - Approved office equipment
# - Required software
# - Business-related internet or communication expenses when applicable under California law
#
# ---
#
# ## Meal Allowance
# Employees traveling for business are eligible for reimbursement up t
# --------------------------------------------------------------------------------
# Result 3
# Document: Business Travel Policy
# File: Business Travel Policy.md
# Page:
# Chunk ID: c31d50567f59a0412b11887ede48b5ba
# Distance: 0.4354  (lower = more similar)
# Snippet:
# # Business Travel Policy – California Employees
#
# ## Purpose
# This policy establishes guidelines for safe, reasonable, and cost-effective business travel.
#
# ---
#
# ## Scope
# This policy applies to all California employees traveling on behalf of the company.
#
# The company operates primarily on-site in San Diego, California, with approved hybrid work arrangements available.
#
# ---
#
# ## Travel Authorization
# All business travel requires advance manager approval.
#
# International travel may require executive app
# --------------------------------------------------------------------------------

# %% [markdown]
# **Can employees work remotely?**

# %% [markdown]
# Top retrieval results:
#
# Result 1
# Document: Hybrid & Remote Work Policy
# File: Hybrid & Remote Work Policy.md
# Page:
# Chunk ID: 19fe683420cb8d460d594ad5c1bbbce6
# Distance: 0.3395  (lower = more similar)
# Snippet:
# termine eligibility.
#
# ---
#
# ## Hybrid Schedule Expectations
# Approved employees may work remotely on designated days while maintaining regular in-office attendance expectations.
#
# Employees are expected to:
# - Maintain reliable communication
# - Attend required meetings
# - Be available during working hours
# - Fulfill performance expectations
#
# ---
#
# ## Flexible Remote Work Arrangements
# Flexible remote work arrangements may be approved on a temporary or ongoing basis.
#
# Examples include:
# - Temporary remote
# --------------------------------------------------------------------------------
# Result 2
# Document: Hybrid & Remote Work Policy
# File: Hybrid & Remote Work Policy.md
# Page:
# Chunk ID: 9fb2454cf49a8ac4028a4974cfc4841c
# Distance: 0.3571  (lower = more similar)
# Snippet:
# remote work arrangements should be directed to Human Resources.
# --------------------------------------------------------------------------------
# Result 3
# Document: Hybrid & Remote Work Policy
# File: Hybrid & Remote Work Policy.md
# Page:
# Chunk ID: 35fa1737ca687ad74352f97556af6140
# Distance: 0.3571  (lower = more similar)
# Snippet:
# remote work arrangements should be directed to Human Resources.
# --------------------------------------------------------------------------------

# %% [markdown]
# **What expenses require approval?**

# %% [markdown]
# Top retrieval results:
#
# Result 1
# Document: Employee Expense Reimbursement Policy
# File: Employee Expense Reimbursement Policy.md
# Page:
# Chunk ID: 1e7550fd85ff18a82f0f7c1477c1c2e1
# Distance: 0.2602  (lower = more similar)
# Snippet:
# d to:
#
# - $200 per night before taxes and fees
#
# Exceptions require prior management approval.
#
# Employees are expected to select safe, reasonably priced accommodations.
#
# ---
#
# ## Airfare
# Employees should book:
# - Economy class airfare
# - Lowest practical logical fare
#
# Upgrades require executive approval.
#
# ---
#
# ## Non-Reimbursable Expenses
# Examples include:
# - Personal entertainment
# - Traffic violations
# - Personal travel expenses
# - Unapproved upgrades
# - Expenses without receipts
#
# ---
#
# ## Expense Submis
# --------------------------------------------------------------------------------
# Result 2
# Document: Employee Procedure – Travel Requests
# File: Employee Procedure – Travel Requests.md
# Page:
# Chunk ID: 58846fa191eb829b5b9c7f02d48edda7
# Distance: 0.3796  (lower = more similar)
# Snippet:
# $2,000)
# - Passport validation
# - Visa documentation
# - Security review
#
# Employees should coordinate with HR and leadership well in advance.
#
# ---
#
# # 10. Travel Safety Expectations
#
# Employees should:
# - Follow local laws
# - Use reputable transportation
# - Exercise good judgment
# - Report emergencies immediately
#
# ---
#
# # 11. Expense Reporting After Travel
#
# Employees must submit expense reports within 30 days of trip completion.
#
# Refer to the Expense Report Procedure document.
#
# ---
#
# # 12. Questions
#
# Questi
# --------------------------------------------------------------------------------
# Result 3
# Document: Employee Procedure – Expense Reports
# File: Employee Procedure – Expense Reports.md
# Page:
# Chunk ID: 0b4e825913497b39a89fdb4b7ee26abc
# Distance: 0.3810  (lower = more similar)
# Snippet:
# on amount
# - Show transaction date
#
# ---
#
# # 7. Verify Policy Limits
#
# Employees must ensure:
# - Daily meal allowance does not exceed $125/day
# - Hotel rate does not exceed $200/night unless approved
# - Airfare complies with economy class requirements
#
# ---
#
# # 8. Submit Report
#
# Before submitting:
# 1. Review all entries
# 2. Verify receipts are attached
# 3. Confirm accounting categories are correct
#
# Select “Submit.”
#
# ---
#
# # 9. Manager Approval Process
#
# Managers review reports for:
# - Policy compliance
# - Busin
# --------------------------------------------------------------------------------

# %% [markdown]
# **How do I request time off?**

# %% [markdown]
# Top retrieval results:
#
# Result 1
# Document: Employee Procedure – Requesting Time Off
# File: Employee Procedure – Requesting Time Off.md
# Page:
# Chunk ID: 04800c53b2a8572568d15dc79751dad8
# Distance: 0.5132  (lower = more similar)
# Snippet:
# ave |
# | Jury Duty | Court-mandated service |
# | Bereavement | Death of family member |
#
# If uncertain, contact Human Resources.
#
# ---
#
# # 3. Discuss Plans with Manager
#
# Employees should notify their manager as early as possible regarding planned absences.
#
# Recommended notice:
# - 2 weeks minimum for vacations over 3 days
# - 30 days for extended leave whenever possible
# - Same-day notice for illness/emergency
#
# ---
#
# # 4. Submit PTO Request
#
# Employees must submit requests through the TimeOff system.
#
# Requi
# --------------------------------------------------------------------------------
# Result 2
# Document: Employee Procedure – Requesting Time Off
# File: Employee Procedure – Requesting Time Off.md
# Page:
# Chunk ID: c7ac538373d08abe227817465cdaa07f
# Distance: 0.5150  (lower = more similar)
# Snippet:
# # Employee Procedure – Requesting Time Off
#
# ## Purpose
# This procedure outlines the steps employees must follow when requesting Paid Time Off (PTO), sick leave, or other approved absences.
#
# ---
#
# # 1. Review PTO Balance
#
# Before submitting a request:
#
# 1. Log into the TimeOff system.
# 2. Review available PTO balance.
# 3. Confirm accrual availability for the requested dates.
#
# Employees should ensure sufficient accrued PTO is available before submitting vacation requests.
#
# ---
#
# # 2. Determine Type of Le
# --------------------------------------------------------------------------------
# Result 3
# Document: Employee Procedure – Requesting Time Off
# File: Employee Procedure – Requesting Time Off.md
# Page:
# Chunk ID: e28b9b5df507dd6c2f0501fade196c1c
# Distance: 0.5458  (lower = more similar)
# Snippet:
# proved absences
#
# Managers may:
# - Approve
# - Deny
# - Request modified dates
#
# ---
#
# # 6. Employee Notification
#
# Employees will receive notification through the TimeOff once approved or denied.
#
# Employees should not finalize travel arrangements until PTO approval is received.
#
# ---
#
# # 7. Extended Leave Requests
#
# Employees requesting protected or extended leave should:
# 1. Contact HR directly
# 2. Complete required leave documentation
# 3. Provide supporting documentation if required
#
# HR will provide additio
# --------------------------------------------------------------------------------
